# %%
#
import numpy as np 
import pandas as pd
###
df=pd.read_csv('data/real_estate_business_terms_v00000.csv')
##
#

# %%
df.head(20)
# Out:
#     NCOL                  Real_Estate_Terms_and_Definitions
# 0    NaN                                Acceleration clause
# 1    NaN  Also known as an acceleration covenant, this i...
# 2    NaN                                                NaN
# 3    NaN                                  Active contingent
# 4    NaN  When a seller accepts an offer from a buyer, t...
# 5    NaN                                                NaN
# 6    NaN                              Active under contract
# 7    NaN  A house is listed as “active under contract” w...
# 8    NaN                                                NaN
# 9    NaN                                           Addendum
# 10   NaN  If a buyer or seller want to change an existin...
# 11   NaN                                                NaN
# 12   NaN                     Adjustable-rate mortgage (ARM)
# 13   NaN  The interest rate for an adjustable-rate mortg...
# 14   NaN                                                NaN
# ...

# %%
#
##
##  Candidate code Test : Option-2





##
#
